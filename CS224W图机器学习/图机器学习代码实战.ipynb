# %% [markdown]
# # 搭建环境
#
# ## 安装NetworkX环境
# 斯坦福官方课程主页:https://web.stanford.edu/class/cs224w
#
# NetworkX主页:https://networkx.org

# %%
# !pip install numpy pandas matplotlib tqdm networkx -i https://pypi.tuna.tsinghua.edu.cn/simple # 更换为清华大学镜像网站
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import networkx as nx

# %% [markdown]
# ## 设置中文字体

# %%
# 从 Google API 上下载暂存字体放到暂存文件夹下

# !wget 'https://noto-website-2.storage.googleapis.com/pkgs/NotoSansCJKtc-hinted.zip'
# !mkdir /tmp/fonts
# !unzip -o NotoSansCJKtc-hinted.zip -d /tmp/fonts/
# !mv /tmp/fonts/NotoSansMonoCJKtc-Regular.otf /usr/share/fonts/truetype/NotoSansMonoCJKtc-Regular.otf -f
# !rm -rf /tmp/fonts
# !rm NotoSansCJKtc-hinted.zip
# Out:
# --2023-03-17 08:43:00--  https://noto-website-2.storage.googleapis.com/pkgs/NotoSansCJKtc-hinted.zip
# Resolving noto-website-2.storage.googleapis.com (noto-website-2.storage.googleapis.com)... 172.217.194.128, 2404:6800:4003:c04::80
# Connecting to noto-website-2.storage.googleapis.com (noto-website-2.storage.googleapis.com)|172.217.194.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 121247366 (116M) [application/zip]
# Saving to: ‘NotoSansCJKtc-hinted.zip’
#
# NotoSansCJKtc-hinte 100%[===================>] 115.63M  18.1MB/s    in 7.7s
#
# 2023-03-17 08:43:08 (15.0 MB/s) - ‘NotoSansCJKtc-hinted.zip’ saved [121247366/121247366]
#
# Archive:  NotoSansCJKtc-hinted.zip
#   inflating: /tmp/fonts/LICENSE_OFL.txt
#   inflating: /tmp/fonts/NotoSansCJKtc-Black.otf
#   inflating: /tmp/fonts/NotoSansCJKtc-Bold.otf
#   inflating: /tmp/fonts/NotoSansCJKtc-DemiLight.otf
#   inflating: /tmp/fonts/NotoSansCJKtc-Light.otf
# ...

# %%
# 指定字体
import matplotlib.font_manager as font_manager
import matplotlib.pyplot as plt
 
font_dirs = ['/usr/share/fonts/truetype/']
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)
 
for font_file in font_files:
  font_manager.fontManager.addfont(font_file)
 
plt.rcParams['font.family'] = "Noto Sans Mono CJK TC"

# %%
#测试
import numpy as np
import matplotlib.pyplot as plt
 
 
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号
 
x = np.arange(1, 12)
y = x ** 2 + 4
plt.title("Matplotlib中文字体测试")
plt.xlabel("时间(分钟)")
plt.ylabel("金额($)")
plt.plot(x,y)
plt.show()

# %% [markdown]
# # 创建图-NetworkX内置图
#
# 通过利用NetworkX自带的函数与API，创建样例图。

# %%
# 导入库
import networkx as nx


import matplotlib.pyplot as plt # 数据可视化
# %matplotlib inline

# %% [markdown]
# ## 经典图

# %%
# 全连接无向图

G = nx.complete_graph(10)
nx.draw(G)

# %%
# 全图连接数
G.size()
# Out:
# 45

# %%
# 全连接有向图

G = nx.complete_graph(10, nx.DiGraph())
nx.draw(G)

# %%
# 检查是否为有向图

G.is_directed()
# Out:
# True

# %%
# 环状图

G = nx.cycle_graph(10)
nx.draw(G)

# %%
# 梯状图

G = nx.ladder_graph(10)
nx.draw(G)

# %%
# 星状图

G = nx.star_graph(10)
nx.draw(G)

# %%
# 二维矩形网格图

G = nx.grid_2d_graph(3, 5)
nx.draw(G)

# %%
# n维超立方体图

G = nx.hypercube_graph(5)
nx.draw(G)

# %%
# 无标度有向图

G = nx.scale_free_graph(100)
nx.draw(G)

# %%
# 图机器学习经典---空手道俱乐部数据集

G = nx.karate_club_graph()
nx.draw(G, with_labels = True)

# %%
G.nodes[5]["club"]
# Out:
# 'Mr. Hi'

# %%
G.nodes[9]["club"]
# Out:
# 'Officer'

# %%
# 雨果《悲惨世界》人物关系

G = nx.les_miserables_graph()
plt.figure(figsize = (12, 10))
pos = nx.spring_layout(G, seed = 1) # 可以设置图像的布局
nx.draw(G, pos, with_labels = True)
